# %%
import warnings
#warnings.filterwarnings('ignore')
import sys
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
sys.path.append('C:\\Users\\elisa\\Documents\\git\\mplstereonet')
sys.path.append('C:\\Users\\elisa\\Documents\\git\\gempy')
import mplstereonet
import gempy as gp
#from importlib import reload
import os
#sys.path.append('C:\\Users\\elisa\\Documents\\git\\remote-geomod') 
import pandas as pn

#import rgeomod

import gdal
import skimage
import scipy
import linecache
from mpl_toolkits.mplot3d import Axes3D
from copy import copy

import seaborn as sns
# Out:
# C:\Users\elisa\Documents\git\gempy\gempy\plotting\visualization.py:36: UserWarning: Steno 3D package is not installed. No 3D online visualization available.
#   warnings.warn('Steno 3D package is not installed. No 3D online visualization available.')
# C:\Users\elisa\Documents\git\gempy\gempy\data_management.py:34: UserWarning: qgrid package is not installed. No interactive dataframes available.
#   warnings.warn('qgrid package is not installed. No interactive dataframes available.')

# %%
import matplotlib
matplotlib.__version__
# Out:
# '2.2.2'

# %%
path_interf = "C:\\Users\\elisa\\Documents\\git\\elthesis\\notebooks\\final\\data\\all_points.csv"
path_orient = "C:\\Users\\elisa\\Documents\\git\\elthesis\\notebooks\\final\\data\\all_foliations.csv"

# %%
resolution = [50,50,50]
extent = np.array([777000, 794500, 6345000, 6353000, -1500, 1000])

# %%
geo_data = gp.create_data(extent = extent, resolution = resolution,
                        path_i = path_interf,
                        path_o = path_orient)
# Out:
# C:\Users\elisa\Anaconda3\envs\rootclone\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
#sorting of lithologies
gp.set_series(geo_data,{'fault_NWSE':('fault_NWSE'),
                        'fault_NS':('fault_NS'),
                        'fault_NESW1':('fault_NESW1'),
                        'fault_NESW2':('fault_NESW2'),
                        'fault_NESW3':('fault_NESW3'),
                        'Trias_Series':('Liassic','Triassic'), 
                        'Carbon_Series':('Carboniferous'), 
                        'Basement_Series':('basement')},
             order_formations=['fault_NWSE','fault_NS',
                                'fault_NESW1','fault_NESW3','fault_NESW2',
                               'Liassic','Triassic','Carboniferous','basement'])

# %%
colordict = {'Liassic':'#015482', 'Triassic': '#9f0052', 'Carboniferous':'#ffbe00','basement':'#728f02',
            'fault_NWSE':'#2a2a2a','fault_NS':'#2a2a2a','fault_NESW2':'#939393','fault_NESW1':'#939393',
             'fault_NESW3':'#939393','fault_NESW4':'#939393' }
geo_data.set_colors(colordict)
# Out:
# <style  type="text/css" >
#     #T_af2c698c_34e8_11e9_b510_e82a44a18926row0_col2 {
#             background-color:  #2a2a2a;
#         }    #T_af2c698c_34e8_11e9_b510_e82a44a18926row1_col2 {
#             background-color:  #2a2a2a;
#         }    #T_af2c698c_34e8_11e9_b510_e82a44a18926row2_col2 {
#             background-color:  #939393;
#         }    #T_af2c698c_34e8_11e9_b510_e82a44a18926row3_col2 {
#             background-color:  #939393;
#         }    #T_af2c698c_34e8_11e9_b510_e82a44a18926row4_col2 {
#             background-color:  #939393;
#         }    #T_af2c698c_34e8_11e9_b510_e82a44a18926row5_col2 {
#             background-color:  #015482;
#         }    #T_af2c698c_34e8_11e9_b510_e82a44a18926row6_col2 {
#             background-color:  #9f0052;
#         }    #T_af2c698c_34e8_11e9_b510_e82a44a18926row7_col2 {
#             background-color:  #ffbe00;
#         }    #T_af2c698c_34e8_11e9_b510_e82a44a18926row8_col2 {
#             background-color:  #728f02;
#         }</style>
# <table id="T_af2c698c_34e8_11e9_b510_e82a44a18926" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >value</th>
#         <th class="col_heading level0 col1" >formation_number</th>
#         <th class="col_heading level0 col2" >color</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_af2c698c_34e8_11e9_b510_e82a44a18926level0_row0" class="row_heading level0 row0" >fault_NWSE</th>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row0_col0" class="data row0 col0" >1</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row0_col1" class="data row0 col1" >1</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row0_col2" class="data row0 col2" >#2a2a2a</td>
#     </tr>    <tr>
#         <th id="T_af2c698c_34e8_11e9_b510_e82a44a18926level0_row1" class="row_heading level0 row1" >fault_NS</th>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row1_col0" class="data row1 col0" >2</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row1_col1" class="data row1 col1" >2</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row1_col2" class="data row1 col2" >#2a2a2a</td>
#     </tr>    <tr>
#         <th id="T_af2c698c_34e8_11e9_b510_e82a44a18926level0_row2" class="row_heading level0 row2" >fault_NESW1</th>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row2_col0" class="data row2 col0" >3</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row2_col1" class="data row2 col1" >3</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row2_col2" class="data row2 col2" >#939393</td>
#     </tr>    <tr>
#         <th id="T_af2c698c_34e8_11e9_b510_e82a44a18926level0_row3" class="row_heading level0 row3" >fault_NESW3</th>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row3_col0" class="data row3 col0" >4</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row3_col1" class="data row3 col1" >4</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row3_col2" class="data row3 col2" >#939393</td>
#     </tr>    <tr>
#         <th id="T_af2c698c_34e8_11e9_b510_e82a44a18926level0_row4" class="row_heading level0 row4" >fault_NESW2</th>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row4_col0" class="data row4 col0" >5</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row4_col1" class="data row4 col1" >5</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row4_col2" class="data row4 col2" >#939393</td>
#     </tr>    <tr>
#         <th id="T_af2c698c_34e8_11e9_b510_e82a44a18926level0_row5" class="row_heading level0 row5" >Liassic</th>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row5_col0" class="data row5 col0" >6</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row5_col1" class="data row5 col1" >6</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row5_col2" class="data row5 col2" >#015482</td>
#     </tr>    <tr>
#         <th id="T_af2c698c_34e8_11e9_b510_e82a44a18926level0_row6" class="row_heading level0 row6" >Triassic</th>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row6_col0" class="data row6 col0" >7</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row6_col1" class="data row6 col1" >7</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row6_col2" class="data row6 col2" >#9f0052</td>
#     </tr>    <tr>
#         <th id="T_af2c698c_34e8_11e9_b510_e82a44a18926level0_row7" class="row_heading level0 row7" >Carboniferous</th>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row7_col0" class="data row7 col0" >8</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row7_col1" class="data row7 col1" >8</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row7_col2" class="data row7 col2" >#ffbe00</td>
#     </tr>    <tr>
#         <th id="T_af2c698c_34e8_11e9_b510_e82a44a18926level0_row8" class="row_heading level0 row8" >basement</th>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row8_col0" class="data row8 col0" >9</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row8_col1" class="data row8 col1" >9</td>
#         <td id="T_af2c698c_34e8_11e9_b510_e82a44a18926row8_col2" class="data row8 col2" >#728f02</td>
#     </tr></tbody>
# </table>

# %%
gp.get_sequential_pile(geo_data)

# %%
gp.plotting.plot_data(geo_data,direction='z',data_type='orientations')
plt.grid(True)
#plt.savefig("C:\\Users\\elisa\\Documents\\Masterarbeit\\Figures\\all_input.png", format='png', dpi=1000)
# Out:
# No handles with labels found to put in legend.

# %%
#Compiling of interpolator function
interp_data = gp.InterpolatorData(geo_data, compile_theano=True,
                                  dtype='float64',theano_optimizer='fast_compile')#, verbose=[])
# Out:
# Compiling theano function...
# Compilation Done!
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  5

# %%
faults1=['fault_NESW1',
 'fault_NESW2',
 'fault_NESW3']
faults2=['fault_NS',
 'fault_NWSE']

# %%
geo_data.faults_relations.loc[faults1,['Trias_Series']] = True
geo_data.faults_relations.loc[faults2,['Trias_Series']] = True
geo_data.faults_relations.loc[faults2,['Carbon_Series']] = True
geo_data.faults_relations
# Out:
#                  fault_NWSE  fault_NS  fault_NESW1  fault_NESW2  fault_NESW3  \
# fault_NWSE            False     False        False        False        False
# fault_NS              False     False        False        False        False
# fault_NESW1           False     False        False        False        False
# fault_NESW2           False     False        False        False        False
# fault_NESW3           False     False        False        False        False
# Trias_Series          False     False        False        False        False
# Carbon_Series         False     False        False        False        False
# Basement_Series       False     False        False        False        False
#
#                  Trias_Series  Carbon_Series  Basement_Series
# fault_NWSE               True           True            False
# fault_NS                 True           True            False
# fault_NESW1              True          False            False
# fault_NESW2              True          False            False
# fault_NESW3              True          False            False
# Trias_Series            False          False            False
# Carbon_Series           False          False            False
# Basement_Series         False          False            False

# %%
interp_data.update_interpolator(geo_data)

# %%
lith_block, fault_block = gp.compute_model(interp_data)

# %%
n, direc = 18, 'y'
gp.plot_section(geo_data, lith_block[0], cell_number=n,  direction=direc, plot_data=True)#, topography=elevation)
gp.plotting.extract_countours(geo_data, interp_data, fb=fault_block, cell_number=n,  direction=direc)
# Out:
# C:\Users\elisa\Documents\git\gempy\gempy\gempy_front.py:955: FutureWarning: gempy plotting functionality will be moved in version 1.2, use gempy.plotting module instead
#   "use gempy.plotting module instead", FutureWarning)

# %%
n, direc = 40, 'y'
gp.plot_section(geo_data, lith_block[0], cell_number=n,  direction=direc, plot_data=True)#, topography=elevation)
gp.plotting.extract_countours(geo_data, interp_data, fb=fault_block, cell_number=n,  direction=direc)
# Out:
# C:\Users\elisa\Documents\git\gempy\gempy\gempy_front.py:955: FutureWarning: gempy plotting functionality will be moved in version 1.2, use gempy.plotting module instead
#   "use gempy.plotting module instead", FutureWarning)
# C:\Users\elisa\Anaconda3\envs\rootclone\lib\site-packages\matplotlib\contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
n, direc = 9, 'x'
gp.plot_section(geo_data, lith_block[0], cell_number=n,  direction=direc, plot_data=True)#, topography=elevation)
gp.plotting.extract_countours(geo_data, interp_data, fb=fault_block, cell_number=n,  direction=direc)
# Out:
# C:\Users\elisa\Documents\git\gempy\gempy\gempy_front.py:955: FutureWarning: gempy plotting functionality will be moved in version 1.2, use gempy.plotting module instead
#   "use gempy.plotting module instead", FutureWarning)
# C:\Users\elisa\Anaconda3\envs\rootclone\lib\site-packages\matplotlib\contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
n, direc = 22, 'x'
gp.plot_section(geo_data, lith_block[0], cell_number=n,  direction=direc, plot_data=True)#, topography=elevation)
gp.plotting.extract_countours(geo_data, interp_data, fb=fault_block, cell_number=n,  direction=direc)
# Out:
# C:\Users\elisa\Documents\git\gempy\gempy\gempy_front.py:955: FutureWarning: gempy plotting functionality will be moved in version 1.2, use gempy.plotting module instead
#   "use gempy.plotting module instead", FutureWarning)
# C:\Users\elisa\Anaconda3\envs\rootclone\lib\site-packages\matplotlib\contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
n, direc = 32, 'x'
gp.plot_section(geo_data, lith_block[0], cell_number=n,  direction=direc, plot_data=True)#, topography=elevation)
gp.plotting.extract_countours(geo_data, interp_data, fb=fault_block, cell_number=n,  direction=direc)
# Out:
# C:\Users\elisa\Documents\git\gempy\gempy\gempy_front.py:955: FutureWarning: gempy plotting functionality will be moved in version 1.2, use gempy.plotting module instead
#   "use gempy.plotting module instead", FutureWarning)
# C:\Users\elisa\Anaconda3\envs\rootclone\lib\site-packages\matplotlib\contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
n, direc = 44, 'x'
gp.plot_section(geo_data, lith_block[0], cell_number=n,  direction=direc, plot_data=True)#, topography=elevation)
gp.plotting.extract_countours(geo_data, interp_data, fb=fault_block, cell_number=n,  direction=direc)
# Out:
# C:\Users\elisa\Documents\git\gempy\gempy\gempy_front.py:955: FutureWarning: gempy plotting functionality will be moved in version 1.2, use gempy.plotting module instead
#   "use gempy.plotting module instead", FutureWarning)
# C:\Users\elisa\Anaconda3\envs\rootclone\lib\site-packages\matplotlib\contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
#topography
path_dtm='C:\\Users\\elisa\\Documents\\Ales\\DISTRIB_2018\\MNT\\MNT_Dx25m_ALES_L93.asc'
folder= "C:\\Users\\elisa\\Documents\\git\\MSc\\GempyTopography\\unwichtig"
xyz_path = "C:\\Users\\elisa\\Documents\\git\\MSc\\GempyTopography\\XYZ.csv"

# %%
from gempy.utils import topography

# %%
elevation = topography.DEM(path_dtm, geo_data,output_path = folder,interpdata=interp_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ed18c82f5778> in <module>()
# ----> 1 elevation = topography.DEM(path_dtm, geo_data,output_path = folder,interpdata=interp_data)
#
# NameError: name 'geo_data' is not defined

# %%
elevation.xyz_box_resized.shape
# Out:
# (50, 50, 3)

# %%
xmap = elevation.xyz_box_resized[:,:,0].ravel()
ymap = elevation.xyz_box_resized[:,:,1].ravel()
zmap = elevation.xyz_box_resized[:,:,2].ravel()
elevation_resized = np.stack((xmap,ymap,zmap),axis=1)

# %%
lith_map, fault_map = gp.compute_model_at(elevation_resized, interp_data)

# %%
gp.plotting.plot_map(geo_data, geomap=lith_map[0].reshape(50,50))
#gp.plotting.extract_countours(geo_data,interp_data, fb=fault_map, cell_number=0)

# %%
np.save('geomap_initial.npy', a)

# %%
geomap = np.load('geomap_initial.npy')

# %%
#faults
gp.plot_section(geo_data, fault_block[2], cell_number=5,  direction='z', plot_data=True)
gp.plot_section(geo_data, fault_block[0], cell_number=5,  direction='z', plot_data=True)
# Out:
# ..\\..\\..\\gempy\gempy\gempy_front.py:955: FutureWarning: gempy plotting functionality will be moved in version 1.2, use gempy.plotting module instead
#   "use gempy.plotting module instead", FutureWarning)

# %%
ver , sim = gp.get_surfaces(interp_data,lith_block[1],(fault_block[1], fault_block[3], fault_block[5], fault_block[7],fault_block[9]))

# %%
gp.plotting.plot_surfaces_3D(geo_data, ver, sim, plot_data=False)
# Out:
# closing vtk
